# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob

# %%
MCACapacity = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/processed/starter-kits/Kenya/Results/MCACapacity.csv")
MCACapacity
# Out:
#                                technology dst_region region agent sector  \
# 0                     Biomass Power Plant      Kenya  Kenya    A1  power
# 1                  Geothermal Power Plant      Kenya  Kenya    A1  power
# 2   Large Hydropower Plant (Dam) (>100MW)      Kenya  Kenya    A1  power
# 3              Light Fuel Oil Power Plant      Kenya  Kenya    A1  power
# 4      Medium Hydropower Plant (10-100MW)      Kenya  Kenya    A1  power
# ..                                    ...        ...    ...   ...    ...
# 72            Crude Oil Refinery Option 1      Kenya  Kenya    A1    oil
# 73            Crude Oil Refinery Option 2      Kenya  Kenya    A1    oil
# 74            Crude Oil Refinery Option 2      Kenya  Kenya    A1    oil
# 75            Crude Oil Refinery Option 2      Kenya  Kenya    A1    oil
# 76            Crude Oil Refinery Option 2      Kenya  Kenya    A1    oil
#
#         type  year   capacity
# 0   retrofit  2020     2.7864
# 1   retrofit  2020    12.9722
# 2   retrofit  2020    15.4490
# 3   retrofit  2020     8.9010
# 4   retrofit  2020     7.7028
# ..       ...   ...        ...
# 72  retrofit  2040   372.5747
# 73  retrofit  2040     5.4496
# 74  retrofit  2040  1000.0000
# 75  retrofit  2040   999.9997
# 76  retrofit  2040  1000.0004
#
# [77 rows x 8 columns]

# %%
MCACapacity_summed = MCACapacity.groupby(["technology", "sector", "year"]).sum().reset_index()
MCACapacity_summed
# Out:
#                                technology sector  year   capacity
# 0                     Biomass Power Plant  power  2020     2.7864
# 1                     Biomass Power Plant  power  2025     2.5078
# 2                     Biomass Power Plant  power  2030     2.2570
# 3                     Biomass Power Plant  power  2035     2.0313
# 4                     Biomass Power Plant  power  2040     1.8282
# 5             Crude Oil Refinery Option 1    oil  2020   100.0000
# 6             Crude Oil Refinery Option 1    oil  2025   280.4255
# 7             Crude Oil Refinery Option 1    oil  2030   510.3251
# 8             Crude Oil Refinery Option 1    oil  2035   885.8523
# 9             Crude Oil Refinery Option 1    oil  2040  1258.4270
# 10            Crude Oil Refinery Option 2    oil  2020   100.0000
# 11            Crude Oil Refinery Option 2    oil  2025     5.4496
# 12            Crude Oil Refinery Option 2    oil  2030  1005.4496
# 13            Crude Oil Refinery Option 2    oil  2035  2005.4493
# 14            Crude Oil Refinery Option 2    oil  2040  3005.4497
# 15                 Geothermal Power Plant  power  2020    12.9722
# 16                 Geothermal Power Plant  power  2025    25.9445
# 17                 Geothermal Power Plant  power  2030    24.7770
# 18                 Geothermal Power Plant  power  2035    23.7262
# 19                 Geothermal Power Plant  power  2040    22.7806
# 20  Large Hydropower Plant (Dam) (>100MW)  power  2020    15.4490
# 21  Large Hydropower Plant (Dam) (>100MW)  power  2025    13.9041
# 22  Large Hydropower Plant (Dam) (>100MW)  power  2030    12.5137
# 23  Large Hydropower Plant (Dam) (>100MW)  power  2035    11.2624
# 24  Large Hydropower Plant (Dam) (>100MW)  power  2040    10.1361
# 25             Light Fuel Oil Power Plant  power  2020     8.9010
# 26             Light Fuel Oil Power Plant  power  2025    17.8020
# 27             Light Fuel Oil Power Plant  power  2030   315.1530
# 28             Light Fuel Oil Power Plant  power  2035   612.0939
# 29             Light Fuel Oil Power Plant  power  2040   908.6657
# 30     Medium Hydropower Plant (10-100MW)  power  2020     7.7028
# 31     Medium Hydropower Plant (10-100MW)  power  2025     6.9326
# 32     Medium Hydropower Plant (10-100MW)  power  2030     6.2393
# 33     Medium Hydropower Plant (10-100MW)  power  2035     5.6154
# 34     Medium Hydropower Plant (10-100MW)  power  2040     5.0538
# 35                    Nuclear Power Plant  power  2025   160.8692
# 36                    Nuclear Power Plant  power  2030   160.8692
# 37                    Nuclear Power Plant  power  2035   160.8692
# 38                    Nuclear Power Plant  power  2040   160.8692
# 39           Oil Fired Gas Turbine (SCGT)  power  2020    13.8391
# 40           Oil Fired Gas Turbine (SCGT)  power  2025   320.9282
# 41           Oil Fired Gas Turbine (SCGT)  power  2030   319.6827
# 42           Oil Fired Gas Turbine (SCGT)  power  2035   318.5618
# 43           Oil Fired Gas Turbine (SCGT)  power  2040   317.5529
# 44                           Onshore Wind  power  2020     9.5976
# 45                           Onshore Wind  power  2025     8.6378
# 46                           Onshore Wind  power  2030     7.7741
# 47                           Onshore Wind  power  2035     6.9967
# 48                           Onshore Wind  power  2040     6.2970
# 49    Solar PV (Distributed with Storage)  power  2020     1.1715
# 50    Solar PV (Distributed with Storage)  power  2025     1.0544
# 51    Solar PV (Distributed with Storage)  power  2030     0.9489
# 52    Solar PV (Distributed with Storage)  power  2035     0.8540
# 53    Solar PV (Distributed with Storage)  power  2040     0.7686
# 54                     Solar PV (Utility)  power  2020     0.7430
# 55                     Solar PV (Utility)  power  2025     0.6687
# 56                     Solar PV (Utility)  power  2030     0.6019
# 57                     Solar PV (Utility)  power  2035     0.5417
# 58                     Solar PV (Utility)  power  2040     0.4875

# %%
sns.lineplot(data=MCACapacity_summed[(MCACapacity_summed.sector=="power")], x="year", y="capacity", hue="technology")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.lineplot(data=MCACapacity_summed[MCACapacity_summed.sector=="oil"], x="year", y="capacity", hue="technology")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
prices = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/processed/starter-kits/Kenya/Results/MCAPrices.csv")
prices_summed = prices.groupby(["commodity","year"]).sum("prices").reset_index()
prices_summed
# Out:
#       commodity  year    prices
# 0          CO2f  2020    6.0000
# 1          CO2f  2025    5.4000
# 2          CO2f  2030    4.8600
# 3          CO2f  2035    4.3740
# 4          CO2f  2040    3.9366
# 5       biomass  2020   10.5600
# 6       biomass  2025   10.5600
# 7       biomass  2030   10.5600
# 8       biomass  2035   10.5600
# 9       biomass  2040   10.5600
# 10         coal  2020   30.6000
# 11         coal  2025   31.8000
# 12         coal  2030   33.0000
# 13         coal  2035   34.2000
# 14         coal  2040   35.4000
# 15    crude_oil  2020   73.2000
# 16    crude_oil  2025   76.5600
# 17    crude_oil  2030   85.6200
# 18    crude_oil  2035   93.5100
# 19    crude_oil  2040  101.4000
# 20  electricity  2020    6.0000
# 21  electricity  2025    8.8752
# 22  electricity  2030   12.1866
# 23  electricity  2035   12.0402
# 24  electricity  2040   11.6718
# 25          gas  2020   51.6000
# 26          gas  2025   56.7000
# 27          gas  2030   61.8000
# 28          gas  2035   63.9000
# 29          gas  2040   66.0000
# 30          hfo  2020   53.2200
# 31          hfo  2025   79.0296
# 32          hfo  2030   73.9428
# 33          hfo  2035   69.3204
# 34          hfo  2040   65.2920
# 35          lfo  2020   88.5000
# 36          lfo  2025   79.0296
# 37          lfo  2030   73.9428
# 38          lfo  2035   69.3204
# 39          lfo  2040   65.2920

# %%
sns.lineplot(data=prices_summed, x="year", y="prices", hue="commodity")
# Out:
# <AxesSubplot:xlabel='year', ylabel='prices'>

# %% [markdown]
# ## Supply

# %%
path = "/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/processed/starter-kits/Kenya/Results/Power/Supply/"
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df['file'] = filename.split("/")[-1].split(".")[0]
    li.append(df)

supply = pd.concat(li, axis=0, ignore_index=True)
supply
# Out:
#      Unnamed: 0    commodity region                             technology  \
# 0             0         CO2f  Kenya                    Biomass Power Plant
# 1             1         CO2f  Kenya                    Biomass Power Plant
# 2             2  electricity  Kenya                    Biomass Power Plant
# 3             3  electricity  Kenya                 Geothermal Power Plant
# 4             4  electricity  Kenya  Large Hydropower Plant (Dam) (>100MW)
# ..          ...          ...    ...                                    ...
# 180          20  electricity  Kenya                    Nuclear Power Plant
# 181          21  electricity  Kenya           Oil Fired Gas Turbine (SCGT)
# 182          22  electricity  Kenya                           Onshore Wind
# 183          23  electricity  Kenya    Solar PV (Distributed with Storage)
# 184          24  electricity  Kenya                     Solar PV (Utility)
#
#      year    supply  file
# 0    2040   91.4079  2040
# 1    2045   82.2671  2040
# 2    2040    0.9141  2040
# 3    2040   17.9966  2040
# 4    2040    4.8653  2040
# ..    ...       ...   ...
# 180  2035  136.7388  2030
# 181  2035  254.8494  2030
# 182  2035    1.4693  2030
# 183  2035    0.2733  2030
# 184  2035    0.1733  2030
#
# [185 rows x 7 columns]

# %%
electricity_supply = supply[supply.commodity=="electricity"]
electricity_supply
# Out:
#      Unnamed: 0    commodity region                             technology  \
# 2             2  electricity  Kenya                    Biomass Power Plant
# 3             3  electricity  Kenya                 Geothermal Power Plant
# 4             4  electricity  Kenya  Large Hydropower Plant (Dam) (>100MW)
# 5             5  electricity  Kenya             Light Fuel Oil Power Plant
# 6             6  electricity  Kenya             Light Fuel Oil Power Plant
# ..          ...          ...    ...                                    ...
# 180          20  electricity  Kenya                    Nuclear Power Plant
# 181          21  electricity  Kenya           Oil Fired Gas Turbine (SCGT)
# 182          22  electricity  Kenya                           Onshore Wind
# 183          23  electricity  Kenya    Solar PV (Distributed with Storage)
# 184          24  electricity  Kenya                     Solar PV (Utility)
#
#      year    supply  file
# 2    2040    0.9141  2040
# 3    2040   17.9966  2040
# 4    2040    4.8653  2040
# 5    2040   12.5048  2040
# 6    2040  238.5217  2040
# ..    ...       ...   ...
# 180  2035  136.7388  2030
# 181  2035  254.8494  2030
# 182  2035    1.4693  2030
# 183  2035    0.2733  2030
# 184  2035    0.1733  2030
#
# [172 rows x 7 columns]

# %%
elec_summed = electricity_supply.groupby(["commodity", "region", "technology", "year"]).sum().reset_index()
elec_summed
# Out:
#       commodity region           technology  year  Unnamed: 0    supply
# 0   electricity  Kenya  Biomass Power Plant  2020           2    1.3932
# 1   electricity  Kenya  Biomass Power Plant  2025          13    2.5078
# 2   electricity  Kenya  Biomass Power Plant  2030          14    2.2570
# 3   electricity  Kenya  Biomass Power Plant  2035          15    2.0312
# 4   electricity  Kenya  Biomass Power Plant  2040          16    1.8282
# ..          ...    ...                  ...   ...         ...       ...
# 67  electricity  Kenya   Solar PV (Utility)  2035          37    0.3466
# 68  electricity  Kenya   Solar PV (Utility)  2040          40    0.3120
# 69  electricity  Kenya   Solar PV (Utility)  2045          43    0.2808
# 70  electricity  Kenya   Solar PV (Utility)  2050          99  411.8720
# 71  electricity  Kenya   Solar PV (Utility)  2055         120  411.6193
#
# [72 rows x 6 columns]

# %%
sns.lineplot(data=elec_summed, x="year", y="supply", hue="technology")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
