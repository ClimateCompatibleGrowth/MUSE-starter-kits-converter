# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
MCACapacity = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/processed/starter-kits/Kenya/Results/MCACapacity.csv")
MCACapacity
# Out:
#                                technology dst_region region agent  \
# 0                               gasboiler      Kenya  Kenya    A1
# 1                     Biomass Power Plant      Kenya  Kenya    A1
# 2                  Geothermal Power Plant      Kenya  Kenya    A1
# 3   Large Hydropower Plant (Dam) (>100MW)      Kenya  Kenya    A1
# 4              Light Fuel Oil Power Plant      Kenya  Kenya    A1
# ..                                    ...        ...    ...   ...
# 73            Crude Oil Refinery Option 1      Kenya  Kenya    A1
# 74            Crude Oil Refinery Option 2      Kenya  Kenya    A1
# 75            Crude Oil Refinery Option 2      Kenya  Kenya    A1
# 76            Crude Oil Refinery Option 2      Kenya  Kenya    A1
# 77            Crude Oil Refinery Option 2      Kenya  Kenya    A1
#
#          sector      type  year   capacity
# 0   residential  retrofit  2020    10.0000
# 1         power  retrofit  2020     2.7864
# 2         power  retrofit  2020    12.9722
# 3         power  retrofit  2020    15.4490
# 4         power  retrofit  2020     8.9010
# ..          ...       ...   ...        ...
# 73          oil  retrofit  2040   372.5747
# 74          oil  retrofit  2040    32.0436
# 75          oil  retrofit  2040  1000.0000
# 76          oil  retrofit  2040  1000.0000
# 77          oil  retrofit  2040  1000.0000
#
# [78 rows x 8 columns]

# %%
MCACapacity_summed = MCACapacity.groupby(["technology", "sector", "year", "agent"]).sum().reset_index()
MCACapacity_summed
# Out:
#              technology       sector  year agent  capacity
# 0   Biomass Power Plant        power  2020    A1    2.7864
# 1   Biomass Power Plant        power  2025    A1    2.5078
# 2   Biomass Power Plant        power  2030    A1    2.2570
# 3   Biomass Power Plant        power  2035    A1    2.0313
# 4   Biomass Power Plant        power  2040    A1    1.8282
# ..                  ...          ...   ...   ...       ...
# 58            gasboiler  residential  2020    A1   10.0000
# 59            gasboiler  residential  2025    A1    8.0000
# 60            gasboiler  residential  2030    A1    6.4000
# 61            gasboiler  residential  2035    A1    5.1200
# 62            gasboiler  residential  2040    A1    4.0920
#
# [63 rows x 5 columns]

# %%
sns.lineplot(data=MCACapacity_summed[(MCACapacity_summed.sector=="power")], x="year", y="capacity", hue="technology", style="agent")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.lineplot(data=MCACapacity_summed[MCACapacity_summed.sector=="oil"], x="year", y="capacity", hue="technology")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
prices = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/processed/starter-kits/Kenya/Results/MCAPrices.csv")
prices_summed = prices.groupby(["commodity","year"]).sum("prices").reset_index()
prices_summed
# Out:
#       commodity  year    prices
# 0       biomass  2020   10.5600
# 1       biomass  2025   10.5600
# 2       biomass  2030   10.5600
# 3       biomass  2035   10.5600
# 4       biomass  2040   10.5600
# 5          coal  2020   30.6000
# 6          coal  2025   31.8000
# 7          coal  2030   33.0000
# 8          coal  2035   34.2000
# 9          coal  2040   35.4000
# 10    crude_oil  2020   73.2000
# 11    crude_oil  2025   76.5600
# 12    crude_oil  2030   85.6200
# 13    crude_oil  2035   93.5100
# 14    crude_oil  2040  101.4000
# 15  electricity  2025    9.8736
# 16  electricity  2030    7.8666
# 17  electricity  2035    6.9786
# 18  electricity  2040    6.5376
# 19          gas  2020   51.6000
# 20          gas  2025   56.7000
# 21          gas  2030   61.8000
# 22          gas  2035   63.9000
# 23          gas  2040   66.0000
# 24          hfo  2020   53.2200
# 25          hfo  2025   13.0596
# 26          hfo  2030   14.5698
# 27          hfo  2035   15.8850
# 28          hfo  2040   17.1996
# 29          lfo  2020   88.5000
# 30          lfo  2025   13.0596
# 31          lfo  2030   14.5698
# 32          lfo  2035   15.8850
# 33          lfo  2040   17.1996

# %%
sns.lineplot(data=prices_summed, x="year", y="prices", hue="commodity")
# Out:
# <AxesSubplot:xlabel='year', ylabel='prices'>
