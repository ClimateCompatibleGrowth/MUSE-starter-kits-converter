# %%
import pandas as pd

# %%
global_commodities = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/processed/starter-kits/Kenya/input/GlobalCommodities.csv")
global_commodities
# Out:
#             Commodity  CommodityType CommodityName  \
# 0           Crude oil         Energy     crude_oil
# 1             Biomass         Energy       biomass
# 2                Coal         Energy          coal
# 3      Light Fuel Oil         Energy           LFO
# 4      Heavy Fuel Oil         Energy           HFO
# 5         Natural Gas         Energy           gas
# 6   CO2fuelcombustion  Environmental          CO2f
# 7          geothermal         Energy    geothermal
# 8               hydro         Energy         hydro
# 9               solar         Energy         solar
# 10            uranium         Energy       uranium
# 11               wind         Energy          wind
# 12        electricity         Energy   electricity
# 13               heat         Energy          heat
#
#     CommodityEmissionFactor_CO2  HeatRate       Unit
# 0                          73.3         1  kg CO2/GJ
# 1                         100.0         1  kg CO2/GJ
# ...

# %%
power_techno = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/processed/starter-kits/Kenya/technodata/power/Technodata.csv")
power_techno
# Out:
#              ProcessName RegionName  Time  Level        cap_par cap_exp  \
# 0                   Unit          -  Year      -  MUS$2010/PJ_a       -
# 1    Biomass Power Plant      Kenya  2020  fixed      2500000.0     1.0
# 2       CSP with Storage      Kenya  2020  fixed      5797000.0     1.0
# 3    CSP without Storage      Kenya  2020  fixed      4058000.0     1.0
# 4       Coal Power Plant      Kenya  2020  fixed      2500000.0     1.0
# ..                   ...        ...   ...    ...            ...     ...
# 104   Solar PV (Utility)      Kenya  2015  fixed      2165000.0     1.0
# 105   Solar PV (Utility)      Kenya  2025  fixed       984000.0     1.0
# 106   Solar PV (Utility)      Kenya  2030  fixed       886000.0     1.0
# 107   Solar PV (Utility)      Kenya  2040  fixed       723000.0     1.0
# 108   Solar PV (Utility)      Kenya  2050  fixed       723000.0     1.0
#
#          fix_par fix_exp      var_par var_exp  ... TotalCapacityLimit  \
# ...

# %%
power_unique = list(pd.unique(power_techno.Fuel))
print(power_unique)
commodities_unique = list(pd.unique(global_commodities.CommodityName))
commodities_unique
# Out:
# ['-', 'biomass', 'solar', 'coal', 'gas', 'geothermal', 'hydro', 'LFO', 'uranium', 'wind', 'HFO']
# ['crude_oil',
#  'biomass',
#  'coal',
#  'LFO',
#  'HFO',
#  'gas',
#  'CO2f',
#  'geothermal',
#  'hydro',
#  'solar',
#  'uranium',
#  'wind',
#  'electricity',
#  'heat']

# %%
list(set(commodities_unique) - set(power_unique))
# Out:
# ['CO2f', 'electricity', 'heat', 'crude_oil']
