# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
oil = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/raw/starter-kits/kenya/Table5_KEN.csv")
oil
# Out:
#                     Technology                     Parameter  \
# 0  Crude Oil Refinery Option 1   Capital Cost ($/kW in 2020)
# 1  Crude Oil Refinery Option 2   Capital Cost ($/kW in 2020)
# 2  Crude Oil Refinery Option 1  Variable Cost ($/GJ in 2020)
# 3  Crude Oil Refinery Option 2  Variable Cost ($/GJ in 2020)
# 4  Crude Oil Refinery Option 1      Operational Life (years)
# 5  Crude Oil Refinery Option 2      Operational Life (years)
# 6  Crude Oil Refinery Option 1                  Output Ratio
# 7  Crude Oil Refinery Option 2                  Output Ratio
#
#                Value
# 0               24.1
# 1               24.1
# 2            0.71775
# 3            0.71775
# 4                 35
# 5                 35
# 6  0.9 LFO : 0.1 HFO
# 7  0.8 LFO : 0.2 HFO

# %%
oil["RegionName"] = "kenya"
oil["Time"] = "2020"
oil["Level"] = "fixed"
oil["cap_exp"] = 1
oil["fix_exp"] = 1
oil["var_par"] = 0
oil["var_exp"] = 1
oil["Type"] = "energy"
oil["EndUse"] = "oil"
oil["Agent2"] = 1
oil["InterestRate"] = 0.1
oil["MaxCapacityAddition"] = 20
oil["MaxCapacityGrowth"] = 20
oil["TotalCapacityLimit"] = 20

oil = oil.reset_index()
oil
# Out:
#    index                   Technology                     Parameter  \
# 0      0  Crude Oil Refinery Option 1   Capital Cost ($/kW in 2020)
# 1      1  Crude Oil Refinery Option 2   Capital Cost ($/kW in 2020)
# 2      2  Crude Oil Refinery Option 1  Variable Cost ($/GJ in 2020)
# 3      3  Crude Oil Refinery Option 2  Variable Cost ($/GJ in 2020)
# 4      4  Crude Oil Refinery Option 1      Operational Life (years)
# 5      5  Crude Oil Refinery Option 2      Operational Life (years)
# 6      6  Crude Oil Refinery Option 1                  Output Ratio
# 7      7  Crude Oil Refinery Option 2                  Output Ratio
#
#                Value RegionName  Time  Level  cap_exp  fix_exp  var_par  \
# 0               24.1      kenya  2020  fixed        1        1        0
# 1               24.1      kenya  2020  fixed        1        1        0
# 2            0.71775      kenya  2020  fixed        1        1        0
# ...

# %%
oil_renamed = oil.rename(columns={"Capital Cost ($/kW in 2020)": "cap_par", "Operational Life (years)": "TechnicalLife", "Technology": "ProcessName"})
oil_renamed
# Out:
#    index                  ProcessName                     Parameter  \
# 0      0  Crude Oil Refinery Option 1   Capital Cost ($/kW in 2020)
# 1      1  Crude Oil Refinery Option 2   Capital Cost ($/kW in 2020)
# 2      2  Crude Oil Refinery Option 1  Variable Cost ($/GJ in 2020)
# 3      3  Crude Oil Refinery Option 2  Variable Cost ($/GJ in 2020)
# 4      4  Crude Oil Refinery Option 1      Operational Life (years)
# 5      5  Crude Oil Refinery Option 2      Operational Life (years)
# 6      6  Crude Oil Refinery Option 1                  Output Ratio
# 7      7  Crude Oil Refinery Option 2                  Output Ratio
#
#                Value RegionName  Time  Level  cap_exp  fix_exp  var_par  \
# 0               24.1      kenya  2020  fixed        1        1        0
# 1               24.1      kenya  2020  fixed        1        1        0
# 2            0.71775      kenya  2020  fixed        1        1        0
# ...

# %%
oil_renamed = oil_renamed.drop(columns="Output Ratio")
oil_renamed
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-5a72c9cb01ef> in <module>
# ----> 1 oil_renamed = oil_renamed.drop(columns="Output Ratio")
#       2 oil_renamed
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
muse_technodata = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/external/muse_data/default/technodata/gas/Technodata.csv")
muse_technodata
# Out:
#   ProcessName RegionName  Time  Level        cap_par cap_exp      fix_par  \
# 0        Unit          -  Year      -  MUS$2010/PJ_a       -  MUS$2010/PJ
# 1  gassupply1         R1  2020  fixed              0       1            0
#
#   fix_exp      var_par var_exp MaxCapacityAddition MaxCapacityGrowth  \
# 0       -  MUS$2010/PJ       -                  PJ                 %
# 1       1         2.55       1                   5                 1
#
#   TotalCapacityLimit TechnicalLife UtilizationFactor ScalingSize efficiency  \
# 0                 PJ         Years                 -          PJ          %
# 1                 60            35               0.9  0.00000189         86
#
#   InterestRate    Type Fuel EndUse    Agent2
# 0            -       -    -      -  Retrofit
# 1          0.1  energy  gas    gas         1

# %%
oil_renamed["Fuel"] = "oil"
oil_renamed["efficiency"] = 1
oil_renamed["ScalingSize"] = 1
oil_renamed["UtilizationFactor"] = 1
oil_renamed["fix_par"] = 1

# %%
oil_renamed = oil_renamed.reindex(muse_technodata.columns, axis=1)
oil_renamed
# Out:
#                    ProcessName RegionName  Time  Level  cap_par  cap_exp  \
# 0  Crude Oil Refinery Option 1      kenya  2020  fixed      NaN        1
# 1  Crude Oil Refinery Option 2      kenya  2020  fixed      NaN        1
# 2  Crude Oil Refinery Option 1      kenya  2020  fixed      NaN        1
# 3  Crude Oil Refinery Option 2      kenya  2020  fixed      NaN        1
# 4  Crude Oil Refinery Option 1      kenya  2020  fixed      NaN        1
# 5  Crude Oil Refinery Option 2      kenya  2020  fixed      NaN        1
# 6  Crude Oil Refinery Option 1      kenya  2020  fixed      NaN        1
# 7  Crude Oil Refinery Option 2      kenya  2020  fixed      NaN        1
#
#    fix_par  fix_exp  var_par  var_exp  MaxCapacityAddition  MaxCapacityGrowth  \
# 0        1        1        0        1                   20                 20
# 1        1        1        0        1                   20                 20
# ...

# %%
oil_renamed = muse_technodata[muse_technodata.ProcessName == "Unit"].append(oil_renamed)
oil_renamed
# Out:
#                    ProcessName RegionName  Time  Level        cap_par cap_exp  \
# 0                         Unit          -  Year      -  MUS$2010/PJ_a       -
# 0  Crude Oil Refinery Option 1      kenya  2020  fixed            NaN       1
# 1  Crude Oil Refinery Option 2      kenya  2020  fixed            NaN       1
# 2  Crude Oil Refinery Option 1      kenya  2020  fixed            NaN       1
# 3  Crude Oil Refinery Option 2      kenya  2020  fixed            NaN       1
# 4  Crude Oil Refinery Option 1      kenya  2020  fixed            NaN       1
# 5  Crude Oil Refinery Option 2      kenya  2020  fixed            NaN       1
# 6  Crude Oil Refinery Option 1      kenya  2020  fixed            NaN       1
# 7  Crude Oil Refinery Option 2      kenya  2020  fixed            NaN       1
#
#        fix_par fix_exp      var_par var_exp MaxCapacityAddition  \
# 0  MUS$2010/PJ       -  MUS$2010/PJ       -                  PJ
# ...

# %%
oil_renamed.to_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/interim/technodata/oil_technodata.csv")

# %%
data_test = {}
data_test['power'] = {"technodata": 1}
data_test['power']['comm_in'] = 2

data_test['oil'] = {"technodata": 1}
data_test['oil']['comm_in'] = 2

data_test

# %%
for key in data_test:
    print(key)
