# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
technoeconomic_data = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/raw/starter-kits/kenya/Table2_KEN.csv")
technoeconomic_data
# Out:
#                                    Technology                    Parameter  \
# 0                         Biomass Power Plant  Capital Cost ($/kW in 2020)
# 1                            Coal Power Plant  Capital Cost ($/kW in 2020)
# 2                      Geothermal Power Plant  Capital Cost ($/kW in 2020)
# 3                  Light Fuel Oil Power Plant  Capital Cost ($/kW in 2020)
# 4                Oil Fired Gas Turbine (SCGT)  Capital Cost ($/kW in 2020)
# ..                                        ...                          ...
# 85                               Onshore Wind      Average Capacity Factor
# 86                              Offshore Wind      Average Capacity Factor
# 87                        Nuclear Power Plant      Average Capacity Factor
# 88  Light Fuel Oil Standalone Generator (1kW)      Average Capacity Factor
# 89        Solar PV (Distributed with Storage)      Average Capacity Factor
#
#       Value
# 0   2500.00
# 1   2500.00
# 2   4000.00
# 3   1200.00
# 4   1450.00
# ..      ...
# 85     0.21
# 86     0.45
# 87     0.85
# 88     0.30
# 89     0.32
#
# [90 rows x 3 columns]

# %%
muse_technodata = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/11-starter-kits/data/external/muse_data/default/technodata/power/Technodata.csv")
muse_technodata
# Out:
#    ProcessName RegionName  Time  Level        cap_par cap_exp      fix_par  \
# 0         Unit          -  Year      -  MUS$2010/PJ_a       -  MUS$2010/PJ
# 1      gasCCGT         R1  2020  fixed    23.78234399       1            0
# 2  windturbine         R1  2020  fixed    36.30771182       1            0
#
#   fix_exp      var_par var_exp  ... TotalCapacityLimit TechnicalLife  \
# 0       -  MUS$2010/PJ       -  ...                 PJ         Years
# 1       1            0       1  ...                 60            35
# 2       1            0       1  ...                 60            25
#
#   UtilizationFactor ScalingSize efficiency InterestRate    Type  Fuel  \
# 0                 -          PJ          %            -       -     -
# 1               0.9  0.00000189         86          0.1  energy   gas
# 2               0.4  0.00000189         86          0.1  energy  wind
#
#         EndUse    Agent2
# 0            -  Retrofit
# 1  electricity         1
# 2  electricity         1
#
# [3 rows x 22 columns]

# %%
technoeconomic_data_wide = technoeconomic_data.pivot(index='Technology', columns='Parameter', values='Value')
technoeconomic_data_wide.insert(0,"RegionName", "R1")
technoeconomic_data_wide.insert(1,"Time", "2020")
technoeconomic_data_wide.insert(2,"Level", "fixed")
technoeconomic_data_wide.insert(3,"cap_exp", 1)
technoeconomic_data_wide.insert(4,"fix_exp", 1)
technoeconomic_data_wide.insert(5,"var_par", 0)
technoeconomic_data_wide.insert(6,"var_exp", 1)
technoeconomic_data_wide.insert(7,"Type", "energy")
technoeconomic_data_wide.insert(8,"EndUse", "Electricity")
technoeconomic_data_wide.insert(9,"Agent2", 1)
technoeconomic_data_wide.insert(9,"InterestRate", 0.1)


technoeconomic_data_wide
# Out:
# Parameter                                 RegionName  Time  Level  cap_exp  \
# Technology
# Biomass Power Plant                               R1  2020  fixed        1
# CSP with Storage                                  R1  2020  fixed        1
# CSP without Storage                               R1  2020  fixed        1
# Coal Power Plant                                  R1  2020  fixed        1
# Gas Power Plant (CCGT)                            R1  2020  fixed        1
# Gas Power Plant (SCGT)                            R1  2020  fixed        1
# Geothermal Power Plant                            R1  2020  fixed        1
# Large Hydropower Plant (Dam) (>100MW)             R1  2020  fixed        1
# Light Fuel Oil Power Plant                        R1  2020  fixed        1
# Light Fuel Oil Standalone Generator (1kW)         R1  2020  fixed        1
# Medium Hydropower Plant (10-100MW)                R1  2020  fixed        1
# Nuclear Power Plant                               R1  2020  fixed        1
# Offshore Wind                                     R1  2020  fixed        1
# Oil Fired Gas Turbine (SCGT)                      R1  2020  fixed        1
# Onshore Wind                                      R1  2020  fixed        1
# Small Hydropower Plant (<10MW)                    R1  2020  fixed        1
# Solar PV (Distributed with Storage)               R1  2020  fixed        1
# Solar PV (Utility)                                R1  2020  fixed        1
#
# Parameter                                  fix_exp  var_par  var_exp    Type  \
# Technology
# Biomass Power Plant                              1        0        1  energy
# CSP with Storage                                 1        0        1  energy
# CSP without Storage                              1        0        1  energy
# Coal Power Plant                                 1        0        1  energy
# Gas Power Plant (CCGT)                           1        0        1  energy
# Gas Power Plant (SCGT)                           1        0        1  energy
# Geothermal Power Plant                           1        0        1  energy
# Large Hydropower Plant (Dam) (>100MW)            1        0        1  energy
# Light Fuel Oil Power Plant                       1        0        1  energy
# Light Fuel Oil Standalone Generator (1kW)        1        0        1  energy
# Medium Hydropower Plant (10-100MW)               1        0        1  energy
# Nuclear Power Plant                              1        0        1  energy
# Offshore Wind                                    1        0        1  energy
# Oil Fired Gas Turbine (SCGT)                     1        0        1  energy
# Onshore Wind                                     1        0        1  energy
# Small Hydropower Plant (<10MW)                   1        0        1  energy
# Solar PV (Distributed with Storage)              1        0        1  energy
# Solar PV (Utility)                               1        0        1  energy
#
# Parameter                                       EndUse  InterestRate  Agent2  \
# Technology
# Biomass Power Plant                        Electricity           0.1       1
# CSP with Storage                           Electricity           0.1       1
# CSP without Storage                        Electricity           0.1       1
# Coal Power Plant                           Electricity           0.1       1
# Gas Power Plant (CCGT)                     Electricity           0.1       1
# Gas Power Plant (SCGT)                     Electricity           0.1       1
# Geothermal Power Plant                     Electricity           0.1       1
# Large Hydropower Plant (Dam) (>100MW)      Electricity           0.1       1
# Light Fuel Oil Power Plant                 Electricity           0.1       1
# Light Fuel Oil Standalone Generator (1kW)  Electricity           0.1       1
# Medium Hydropower Plant (10-100MW)         Electricity           0.1       1
# Nuclear Power Plant                        Electricity           0.1       1
# Offshore Wind                              Electricity           0.1       1
# Oil Fired Gas Turbine (SCGT)               Electricity           0.1       1
# Onshore Wind                               Electricity           0.1       1
# Small Hydropower Plant (<10MW)             Electricity           0.1       1
# Solar PV (Distributed with Storage)        Electricity           0.1       1
# Solar PV (Utility)                         Electricity           0.1       1
#
# Parameter                                  Average Capacity Factor  \
# Technology
# Biomass Power Plant                                           0.50
# CSP with Storage                                              0.45
# CSP without Storage                                           0.45
# Coal Power Plant                                              0.85
# Gas Power Plant (CCGT)                                        0.85
# Gas Power Plant (SCGT)                                        0.85
# Geothermal Power Plant                                        0.79
# Large Hydropower Plant (Dam) (>100MW)                         0.48
# Light Fuel Oil Power Plant                                    0.80
# Light Fuel Oil Standalone Generator (1kW)                     0.30
# Medium Hydropower Plant (10-100MW)                            0.48
# Nuclear Power Plant                                           0.85
# Offshore Wind                                                 0.45
# Oil Fired Gas Turbine (SCGT)                                  0.80
# Onshore Wind                                                  0.21
# Small Hydropower Plant (<10MW)                                0.48
# Solar PV (Distributed with Storage)                           0.32
# Solar PV (Utility)                                            0.32
#
# Parameter                                  Capital Cost ($/kW in 2020)  \
# Technology
# Biomass Power Plant                                             2500.0
# CSP with Storage                                                5797.0
# CSP without Storage                                             4058.0
# Coal Power Plant                                                2500.0
# Gas Power Plant (CCGT)                                          1200.0
# Gas Power Plant (SCGT)                                           700.0
# Geothermal Power Plant                                          4000.0
# Large Hydropower Plant (Dam) (>100MW)                           3000.0
# Light Fuel Oil Power Plant                                      1200.0
# Light Fuel Oil Standalone Generator (1kW)                        750.0
# Medium Hydropower Plant (10-100MW)                              2500.0
# Nuclear Power Plant                                             6137.0
# Offshore Wind                                                   3972.4
# Oil Fired Gas Turbine (SCGT)                                    1450.0
# Onshore Wind                                                    1489.0
# Small Hydropower Plant (<10MW)                                  3000.0
# Solar PV (Distributed with Storage)                             4320.0
# Solar PV (Utility)                                              1378.0
#
# Parameter                                  Efficiency   \
# Technology
# Biomass Power Plant                               0.35
# CSP with Storage                                  1.00
# CSP without Storage                               1.00
# Coal Power Plant                                  0.37
# Gas Power Plant (CCGT)                            0.48
# Gas Power Plant (SCGT)                            0.30
# Geothermal Power Plant                            0.80
# Large Hydropower Plant (Dam) (>100MW)             1.00
# Light Fuel Oil Power Plant                        0.35
# Light Fuel Oil Standalone Generator (1kW)         0.16
# Medium Hydropower Plant (10-100MW)                1.00
# Nuclear Power Plant                               0.33
# Offshore Wind                                     1.00
# Oil Fired Gas Turbine (SCGT)                      0.35
# Onshore Wind                                      1.00
# Small Hydropower Plant (<10MW)                    1.00
# Solar PV (Distributed with Storage)               1.00
# Solar PV (Utility)                                1.00
#
# Parameter                                  Fixed Cost ($/kW/yr in 2020)  \
# Technology
# Biomass Power Plant                                               75.00
# CSP with Storage                                                  57.97
# CSP without Storage                                               40.58
# Coal Power Plant                                                  78.00
# Gas Power Plant (CCGT)                                            35.00
# Gas Power Plant (SCGT)                                            20.00
# Geothermal Power Plant                                           120.00
# Large Hydropower Plant (Dam) (>100MW)                             90.00
# Light Fuel Oil Power Plant                                        35.00
# Light Fuel Oil Standalone Generator (1kW)                         23.00
# Medium Hydropower Plant (10-100MW)                                75.00
# Nuclear Power Plant                                              184.11
# Offshore Wind                                                    158.90
# Oil Fired Gas Turbine (SCGT)                                      45.00
# Onshore Wind                                                      59.56
# Small Hydropower Plant (<10MW)                                    90.00
# Solar PV (Distributed with Storage)                               86.40
# Solar PV (Utility)                                                17.91
#
# Parameter                                  Operational Life (years)
# Technology
# Biomass Power Plant                                            30.0
# CSP with Storage                                               30.0
# CSP without Storage                                            30.0
# Coal Power Plant                                               35.0
# Gas Power Plant (CCGT)                                         30.0
# Gas Power Plant (SCGT)                                         25.0
# Geothermal Power Plant                                         25.0
# Large Hydropower Plant (Dam) (>100MW)                          50.0
# Light Fuel Oil Power Plant                                     25.0
# Light Fuel Oil Standalone Generator (1kW)                      10.0
# Medium Hydropower Plant (10-100MW)                             50.0
# Nuclear Power Plant                                            50.0
# Offshore Wind                                                  25.0
# Oil Fired Gas Turbine (SCGT)                                   25.0
# Onshore Wind                                                   25.0
# Small Hydropower Plant (<10MW)                                 50.0
# Solar PV (Distributed with Storage)                            24.0
# Solar PV (Utility)                                             24.0

# %%
technoeconomic_data_wide = technoeconomic_data_wide.reset_index()
technoeconomic_data_wide_named = technoeconomic_data_wide.rename(columns={"Average Capacity Factor": "UtilizationFactor", "Capital Cost ($/kW in 2020)": "cap_par", "Fixed Cost ($/kW/yr in 2020)": "fix_par", "Operational Life (years)":"TechnicalLife", "Technology":"ProcessName", "Efficiency ": "efficiency"})
technoeconomic_data_wide_named
# Out:
# Parameter                                ProcessName RegionName  Time  Level  \
# 0                                Biomass Power Plant         R1  2020  fixed
# 1                                   CSP with Storage         R1  2020  fixed
# 2                                CSP without Storage         R1  2020  fixed
# 3                                   Coal Power Plant         R1  2020  fixed
# 4                             Gas Power Plant (CCGT)         R1  2020  fixed
# 5                             Gas Power Plant (SCGT)         R1  2020  fixed
# 6                             Geothermal Power Plant         R1  2020  fixed
# 7              Large Hydropower Plant (Dam) (>100MW)         R1  2020  fixed
# 8                         Light Fuel Oil Power Plant         R1  2020  fixed
# 9          Light Fuel Oil Standalone Generator (1kW)         R1  2020  fixed
# 10                Medium Hydropower Plant (10-100MW)         R1  2020  fixed
# 11                               Nuclear Power Plant         R1  2020  fixed
# 12                                     Offshore Wind         R1  2020  fixed
# 13                      Oil Fired Gas Turbine (SCGT)         R1  2020  fixed
# 14                                      Onshore Wind         R1  2020  fixed
# 15                    Small Hydropower Plant (<10MW)         R1  2020  fixed
# 16               Solar PV (Distributed with Storage)         R1  2020  fixed
# 17                                Solar PV (Utility)         R1  2020  fixed
#
# Parameter  cap_exp  fix_exp  var_par  var_exp    Type       EndUse  \
# 0                1        1        0        1  energy  Electricity
# 1                1        1        0        1  energy  Electricity
# 2                1        1        0        1  energy  Electricity
# 3                1        1        0        1  energy  Electricity
# 4                1        1        0        1  energy  Electricity
# 5                1        1        0        1  energy  Electricity
# 6                1        1        0        1  energy  Electricity
# 7                1        1        0        1  energy  Electricity
# 8                1        1        0        1  energy  Electricity
# 9                1        1        0        1  energy  Electricity
# 10               1        1        0        1  energy  Electricity
# 11               1        1        0        1  energy  Electricity
# 12               1        1        0        1  energy  Electricity
# 13               1        1        0        1  energy  Electricity
# 14               1        1        0        1  energy  Electricity
# 15               1        1        0        1  energy  Electricity
# 16               1        1        0        1  energy  Electricity
# 17               1        1        0        1  energy  Electricity
#
# Parameter  InterestRate  Agent2  UtilizationFactor  cap_par  efficiency  \
# 0                   0.1       1               0.50   2500.0        0.35
# 1                   0.1       1               0.45   5797.0        1.00
# 2                   0.1       1               0.45   4058.0        1.00
# 3                   0.1       1               0.85   2500.0        0.37
# 4                   0.1       1               0.85   1200.0        0.48
# 5                   0.1       1               0.85    700.0        0.30
# 6                   0.1       1               0.79   4000.0        0.80
# 7                   0.1       1               0.48   3000.0        1.00
# 8                   0.1       1               0.80   1200.0        0.35
# 9                   0.1       1               0.30    750.0        0.16
# 10                  0.1       1               0.48   2500.0        1.00
# 11                  0.1       1               0.85   6137.0        0.33
# 12                  0.1       1               0.45   3972.4        1.00
# 13                  0.1       1               0.80   1450.0        0.35
# 14                  0.1       1               0.21   1489.0        1.00
# 15                  0.1       1               0.48   3000.0        1.00
# 16                  0.1       1               0.32   4320.0        1.00
# 17                  0.1       1               0.32   1378.0        1.00
#
# Parameter  fix_par  TechnicalLife
# 0            75.00           30.0
# 1            57.97           30.0
# 2            40.58           30.0
# 3            78.00           35.0
# 4            35.00           30.0
# 5            20.00           25.0
# 6           120.00           25.0
# 7            90.00           50.0
# 8            35.00           25.0
# 9            23.00           10.0
# 10           75.00           50.0
# 11          184.11           50.0
# 12          158.90           25.0
# 13           45.00           25.0
# 14           59.56           25.0
# 15           90.00           50.0
# 16           86.40           24.0
# 17           17.91           24.0

# %%
technoeconomic_data_wide_named.reindex(muse_technodata.columns, axis=1)
# Out:
#                                   ProcessName RegionName  Time  Level  \
# 0                         Biomass Power Plant         R1  2020  fixed
# 1                            CSP with Storage         R1  2020  fixed
# 2                         CSP without Storage         R1  2020  fixed
# 3                            Coal Power Plant         R1  2020  fixed
# 4                      Gas Power Plant (CCGT)         R1  2020  fixed
# 5                      Gas Power Plant (SCGT)         R1  2020  fixed
# 6                      Geothermal Power Plant         R1  2020  fixed
# 7       Large Hydropower Plant (Dam) (>100MW)         R1  2020  fixed
# 8                  Light Fuel Oil Power Plant         R1  2020  fixed
# 9   Light Fuel Oil Standalone Generator (1kW)         R1  2020  fixed
# 10         Medium Hydropower Plant (10-100MW)         R1  2020  fixed
# 11                        Nuclear Power Plant         R1  2020  fixed
# 12                              Offshore Wind         R1  2020  fixed
# 13               Oil Fired Gas Turbine (SCGT)         R1  2020  fixed
# 14                               Onshore Wind         R1  2020  fixed
# 15             Small Hydropower Plant (<10MW)         R1  2020  fixed
# 16        Solar PV (Distributed with Storage)         R1  2020  fixed
# 17                         Solar PV (Utility)         R1  2020  fixed
#
#     cap_par  cap_exp  fix_par  fix_exp  var_par  var_exp  MaxCapacityAddition  \
# 0    2500.0        1    75.00        1        0        1                  NaN
# 1    5797.0        1    57.97        1        0        1                  NaN
# 2    4058.0        1    40.58        1        0        1                  NaN
# 3    2500.0        1    78.00        1        0        1                  NaN
# 4    1200.0        1    35.00        1        0        1                  NaN
# 5     700.0        1    20.00        1        0        1                  NaN
# 6    4000.0        1   120.00        1        0        1                  NaN
# 7    3000.0        1    90.00        1        0        1                  NaN
# 8    1200.0        1    35.00        1        0        1                  NaN
# 9     750.0        1    23.00        1        0        1                  NaN
# 10   2500.0        1    75.00        1        0        1                  NaN
# 11   6137.0        1   184.11        1        0        1                  NaN
# 12   3972.4        1   158.90        1        0        1                  NaN
# 13   1450.0        1    45.00        1        0        1                  NaN
# 14   1489.0        1    59.56        1        0        1                  NaN
# 15   3000.0        1    90.00        1        0        1                  NaN
# 16   4320.0        1    86.40        1        0        1                  NaN
# 17   1378.0        1    17.91        1        0        1                  NaN
#
#     MaxCapacityGrowth  TotalCapacityLimit  TechnicalLife  UtilizationFactor  \
# 0                 NaN                 NaN           30.0               0.50
# 1                 NaN                 NaN           30.0               0.45
# 2                 NaN                 NaN           30.0               0.45
# 3                 NaN                 NaN           35.0               0.85
# 4                 NaN                 NaN           30.0               0.85
# 5                 NaN                 NaN           25.0               0.85
# 6                 NaN                 NaN           25.0               0.79
# 7                 NaN                 NaN           50.0               0.48
# 8                 NaN                 NaN           25.0               0.80
# 9                 NaN                 NaN           10.0               0.30
# 10                NaN                 NaN           50.0               0.48
# 11                NaN                 NaN           50.0               0.85
# 12                NaN                 NaN           25.0               0.45
# 13                NaN                 NaN           25.0               0.80
# 14                NaN                 NaN           25.0               0.21
# 15                NaN                 NaN           50.0               0.48
# 16                NaN                 NaN           24.0               0.32
# 17                NaN                 NaN           24.0               0.32
#
#     ScalingSize  efficiency  InterestRate    Type  Fuel       EndUse  Agent2
# 0           NaN        0.35           0.1  energy   NaN  Electricity       1
# 1           NaN        1.00           0.1  energy   NaN  Electricity       1
# 2           NaN        1.00           0.1  energy   NaN  Electricity       1
# 3           NaN        0.37           0.1  energy   NaN  Electricity       1
# 4           NaN        0.48           0.1  energy   NaN  Electricity       1
# 5           NaN        0.30           0.1  energy   NaN  Electricity       1
# 6           NaN        0.80           0.1  energy   NaN  Electricity       1
# 7           NaN        1.00           0.1  energy   NaN  Electricity       1
# 8           NaN        0.35           0.1  energy   NaN  Electricity       1
# 9           NaN        0.16           0.1  energy   NaN  Electricity       1
# 10          NaN        1.00           0.1  energy   NaN  Electricity       1
# 11          NaN        0.33           0.1  energy   NaN  Electricity       1
# 12          NaN        1.00           0.1  energy   NaN  Electricity       1
# 13          NaN        0.35           0.1  energy   NaN  Electricity       1
# 14          NaN        1.00           0.1  energy   NaN  Electricity       1
# 15          NaN        1.00           0.1  energy   NaN  Electricity       1
# 16          NaN        1.00           0.1  energy   NaN  Electricity       1
# 17          NaN        1.00           0.1  energy   NaN  Electricity       1
